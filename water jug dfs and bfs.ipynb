# %%
#Using BFS
from collections import deque
a=[]
def waterJugSolverDFS(jug1, jug2, aim):
    queue = deque([(0, 0)])
    visited = set([(0, 0)])
    parents = {}
    while queue:
        current_state = queue.popleft()
        amt1, amt2 = current_state
        a.append(current_state)
        if amt1 == aim:
            steps = []
            while current_state != (0, 0):
                steps.append(current_state)
                current_state = parents[current_state]
            steps.append((0, 0))
            steps.reverse()
            return steps

        next_states = [
            (jug1, amt2),  
            (amt1, jug2),  
            (0, amt2),     
            (amt1, 0),     
            (min(jug1, amt1 + amt2), max(0, amt1 + amt2 - jug1)),  
            (max(0, amt1 + amt2 - jug2), min(jug2, amt1 + amt2))   
        ]

        for state in next_states:
            if state not in visited:
                queue.append(state)
                visited.add(state)
                parents[state] = current_state

    return None
jug1_capacity=int(input("enter the jug1 value"))
jug2_capacity =int(input("enter the jug2 vaLue"))
desired_quantity=int(input("enter the goal"))
solution = waterJugSolverDFS(jug1_capacity, jug2_capacity, desired_quantity)
if solution:
    for step in solution:
        print(step)
    print(a)
    print("goal reached")
else:
    print("No solution found.")
# Out:
# enter the jug1 value5
# enter the jug2 vaLue3
# enter the goal4
# (0, 0)
# (5, 0)
# (2, 3)
# (2, 0)
# (0, 2)
# (5, 2)
# (4, 3)
# [(0, 0), (5, 0), (0, 3), (5, 3), (2, 3), (3, 0), (2, 0), (3, 3), (0, 2), (5, 1), (5, 2), (0, 1), (4, 3)]
# goal reached

# %%
#USING DFS

from collections import deque
a=[]
def waterJugSolverBFS(jug1, jug2, aim):
    queue = deque([(0, 0)])
    visited = set([(0, 0)])
    parents = {}

    while queue:
        current_state = queue.pop()
        amt1, amt2 = current_state
        a.append(current_state)
        if amt1 == aim:
            steps = []
            while current_state != (0, 0):
                steps.append(current_state)
                current_state = parents[current_state]
            steps.append((0, 0))
            steps.reverse()
            return steps

        next_states = [
            (jug1, amt2),  
            (amt1, jug2),  
            (0, amt2),     
            (amt1, 0),     
            (min(jug1, amt1 + amt2), max(0, amt1 + amt2 - jug1)),  
            (max(0, amt1 + amt2 - jug2), min(jug2, amt1 + amt2))   
        ]

        for state in next_states:
            if state not in visited:
                queue.append(state)
                visited.add(state)
                parents[state] = current_state

    return None
jug1_capacity=int(input("enter the jug1 value"))
jug2_capacity =int(input("enter the jug2 vaLue"))
desired_quantity=int(input("enter the goal"))
solution = waterJugSolverBFS(jug1_capacity, jug2_capacity, desired_quantity)
if solution:
    for step in solution:
        print(step)
    print(a)
    print("goal reached")
else:
    print("No solution found.")
# Out:
# enter the jug1 value5
# enter the jug2 vaLue3
# enter the goal4
# (0, 0)
# (0, 3)
# (3, 0)
# (3, 3)
# (5, 1)
# (0, 1)
# (1, 0)
# (1, 3)
# (4, 0)
# [(0, 0), (0, 3), (3, 0), (3, 3), (5, 1), (0, 1), (1, 0), (1, 3), (4, 0)]
# goal reached
